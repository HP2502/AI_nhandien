# %%
#Kết nối Drive với ggcolab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#KHAI BÁO TẤT CẢ THƯ VIỆN CẦN DÙNG
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator, image
from keras.layers import Dense,Activation,Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras.models import  Sequential

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd

# %%
train_data = '/content/drive/MyDrive/AI/10_Monan/TRAIN'
test_data =  '/content/drive/MyDrive/AI/10_Monan/TEST'
val_data  =  '/content/drive/MyDrive/AI/10_Monan/TEST'

# %%
from keras.engine.data_adapter import train_validation_split
#CHỈNH LẠI TỈ LỆ VÀ PRE-PREPROCESSING DATA

data_scale = ImageDataGenerator(
              rescale=1. / 255,
              shear_range=0.2,
              zoom_range=0.2,
              horizontal_flip=True)

train_input = data_scale.flow_from_directory(train_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
test_input = data_scale.flow_from_directory(test_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
val_input = data_scale.flow_from_directory(val_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
# Out:
# Found 295 images belonging to 10 classes.
# Found 122 images belonging to 10 classes.
# Found 122 images belonging to 10 classes.

# %%
#ĐẶT NHÃN
class_name = ['BÁNH MÌ', 'BÁNH PÍA', 'BÁNH TIÊU', 'BÁNH ƯỚT', 'BÁNH XÈO', 'CÀ RI', 'CƠM TẤM', 'MÌ XÀO', 'PHỞ', 'THỊT KHO TÀU']

#IN NHÃN VÀ ĐẶT GIÁ TRỊ CHO TỪNG PHẦN TỬ
print("labels: ", class_name)
print("match class: ", train_input.class_indices)
print("Tổng cộng các loại mon an: ",train_input.num_classes)
# Out:
# labels:  ['BÁNH MÌ', 'BÁNH PÍA', 'BÁNH TIÊU', 'BÁNH ƯỚT', 'BÁNH XÈO', 'CÀ RI', 'CƠM TẤM', 'MÌ XÀO', 'PHỞ', 'THỊT KHO TÀU']
# match class:  {'BÁNH MÌ': 0, 'BÁNH PÍA': 1, 'BÁNH TIÊU': 2, 'BÁNH ƯỚT': 3, 'BÁNH XÈO': 4, 'CÀ RI': 5, 'CƠM TẤM': 6, 'MÌ XÀO': 7, 'PHỞ': 8, 'THỊT KHO TÀU': 9}
# Tổng cộng các loại mon an:  10

# %%
#XÂY DỰNG MODEL CNN
model=Sequential()

#TRÍCH XUẤT TẬP DỮ LIỆU(FEATURE EXTRACTORS)
#LAYER 1
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same', input_shape=(120,120,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 2
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 3
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

#FULLY CONNECTED LAYER
#Flatten Layer is used to change the dimension of output from convolution layer, which has 3D, to 2D output
model.add(Flatten())

#Dense(512) is a fully-connected layer with 128 hidden units
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(10,activation='softmax'))  #10 class_name
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 120, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 32)       0
#  )
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 512)               14746112
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 15,107,146
# Trainable params: 15,107,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
food_train = model.fit(train_input,batch_size=30,epochs=100,verbose=1,validation_data=val_input)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 133s 13s/step - loss: 25.4834 - accuracy: 0.1085 - val_loss: 2.3005 - val_accuracy: 0.0902
# Epoch 2/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.3946 - accuracy: 0.1017 - val_loss: 2.2952 - val_accuracy: 0.1311
# Epoch 3/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.3114 - accuracy: 0.1153 - val_loss: 2.3023 - val_accuracy: 0.1148
# Epoch 4/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.2994 - accuracy: 0.1254 - val_loss: 2.3023 - val_accuracy: 0.1311
# Epoch 5/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.2954 - accuracy: 0.1186 - val_loss: 2.2839 - val_accuracy: 0.0984
# Epoch 6/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.2955 - accuracy: 0.1220 - val_loss: 2.2965 - val_accuracy: 0.2049
# Epoch 7/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.2490 - accuracy: 0.1356 - val_loss: 2.1855 - val_accuracy: 0.1967
# Epoch 8/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.1865 - accuracy: 0.1864 - val_loss: 2.2770 - val_accuracy: 0.0984
# Epoch 9/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.1741 - accuracy: 0.2068 - val_loss: 2.1623 - val_accuracy: 0.3115
# Epoch 10/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.9883 - accuracy: 0.2678 - val_loss: 1.9690 - val_accuracy: 0.2705
# Epoch 11/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.8510 - accuracy: 0.3085 - val_loss: 1.9129 - val_accuracy: 0.3197
# Epoch 12/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.7834 - accuracy: 0.3322 - val_loss: 1.8715 - val_accuracy: 0.3197
# Epoch 13/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.7216 - accuracy: 0.3797 - val_loss: 1.8888 - val_accuracy: 0.3115
# Epoch 14/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.7534 - accuracy: 0.3288 - val_loss: 1.7835 - val_accuracy: 0.3361
# Epoch 15/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.6679 - accuracy: 0.3797 - val_loss: 1.7983 - val_accuracy: 0.3770
# Epoch 16/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.6000 - accuracy: 0.4169 - val_loss: 1.7886 - val_accuracy: 0.3279
# Epoch 17/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.5970 - accuracy: 0.4136 - val_loss: 1.7465 - val_accuracy: 0.3115
# Epoch 18/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.5424 - accuracy: 0.4475 - val_loss: 1.6288 - val_accuracy: 0.4098
# Epoch 19/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.6240 - accuracy: 0.4169 - val_loss: 1.8149 - val_accuracy: 0.3689
# Epoch 20/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.5192 - accuracy: 0.4949 - val_loss: 1.4813 - val_accuracy: 0.4836
# Epoch 21/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.4644 - accuracy: 0.4576 - val_loss: 1.4976 - val_accuracy: 0.5082
# Epoch 22/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.2899 - accuracy: 0.5525 - val_loss: 1.4388 - val_accuracy: 0.4918
# Epoch 23/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.1544 - accuracy: 0.6068 - val_loss: 1.4630 - val_accuracy: 0.4836
# Epoch 24/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.1955 - accuracy: 0.6000 - val_loss: 1.6015 - val_accuracy: 0.4098
# Epoch 25/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.1141 - accuracy: 0.5864 - val_loss: 1.3774 - val_accuracy: 0.5082
# Epoch 26/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.0839 - accuracy: 0.5763 - val_loss: 1.5635 - val_accuracy: 0.4754
# Epoch 27/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.0032 - accuracy: 0.6508 - val_loss: 1.3578 - val_accuracy: 0.6066
# Epoch 28/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.8196 - accuracy: 0.6983 - val_loss: 1.3265 - val_accuracy: 0.5574
# Epoch 29/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.7343 - accuracy: 0.7356 - val_loss: 1.1659 - val_accuracy: 0.5902
# Epoch 30/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.7236 - accuracy: 0.7085 - val_loss: 1.1928 - val_accuracy: 0.5820
# Epoch 31/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.6493 - accuracy: 0.7593 - val_loss: 1.5099 - val_accuracy: 0.4836
# Epoch 32/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.7372 - accuracy: 0.7220 - val_loss: 1.2641 - val_accuracy: 0.5328
# Epoch 33/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.6463 - accuracy: 0.7763 - val_loss: 1.2535 - val_accuracy: 0.5656
# Epoch 34/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.6683 - accuracy: 0.7695 - val_loss: 1.2522 - val_accuracy: 0.6066
# Epoch 35/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.6113 - accuracy: 0.7661 - val_loss: 1.2572 - val_accuracy: 0.5820
# Epoch 36/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5118 - accuracy: 0.8339 - val_loss: 1.4066 - val_accuracy: 0.5902
# Epoch 37/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5114 - accuracy: 0.8271 - val_loss: 1.2352 - val_accuracy: 0.6148
# Epoch 38/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4536 - accuracy: 0.8407 - val_loss: 1.2393 - val_accuracy: 0.5902
# Epoch 39/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4076 - accuracy: 0.8644 - val_loss: 1.3363 - val_accuracy: 0.5656
# Epoch 40/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4923 - accuracy: 0.8271 - val_loss: 1.2284 - val_accuracy: 0.6230
# Epoch 41/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3952 - accuracy: 0.8576 - val_loss: 1.2344 - val_accuracy: 0.6311
# Epoch 42/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4078 - accuracy: 0.8678 - val_loss: 1.2373 - val_accuracy: 0.6230
# Epoch 43/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3262 - accuracy: 0.8915 - val_loss: 1.0128 - val_accuracy: 0.6311
# Epoch 44/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3063 - accuracy: 0.8780 - val_loss: 1.1571 - val_accuracy: 0.6475
# Epoch 45/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3104 - accuracy: 0.8847 - val_loss: 1.1093 - val_accuracy: 0.6475
# Epoch 46/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3617 - accuracy: 0.8780 - val_loss: 1.3945 - val_accuracy: 0.6311
# Epoch 47/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3942 - accuracy: 0.8508 - val_loss: 1.4726 - val_accuracy: 0.5656
# Epoch 48/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4408 - accuracy: 0.8576 - val_loss: 1.1995 - val_accuracy: 0.6230
# Epoch 49/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3266 - accuracy: 0.8746 - val_loss: 1.1628 - val_accuracy: 0.6475
# Epoch 50/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2821 - accuracy: 0.9186 - val_loss: 1.3261 - val_accuracy: 0.6311
# Epoch 51/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2701 - accuracy: 0.9119 - val_loss: 1.2356 - val_accuracy: 0.6639
# Epoch 52/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1759 - accuracy: 0.9458 - val_loss: 1.2818 - val_accuracy: 0.6475
# Epoch 53/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2989 - accuracy: 0.9051 - val_loss: 1.7241 - val_accuracy: 0.6475
# Epoch 54/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2767 - accuracy: 0.9186 - val_loss: 1.5785 - val_accuracy: 0.5902
# Epoch 55/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3192 - accuracy: 0.9017 - val_loss: 1.3218 - val_accuracy: 0.6639
# Epoch 56/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2473 - accuracy: 0.9153 - val_loss: 1.2497 - val_accuracy: 0.6230
# Epoch 57/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2130 - accuracy: 0.9322 - val_loss: 1.2556 - val_accuracy: 0.6475
# Epoch 58/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1636 - accuracy: 0.9492 - val_loss: 1.2702 - val_accuracy: 0.6475
# Epoch 59/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1290 - accuracy: 0.9559 - val_loss: 1.5044 - val_accuracy: 0.6475
# Epoch 60/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1258 - accuracy: 0.9593 - val_loss: 1.3671 - val_accuracy: 0.6475
# Epoch 61/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0986 - accuracy: 0.9729 - val_loss: 1.6691 - val_accuracy: 0.5820
# Epoch 62/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1572 - accuracy: 0.9424 - val_loss: 1.3439 - val_accuracy: 0.6967
# Epoch 63/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1791 - accuracy: 0.9424 - val_loss: 1.4354 - val_accuracy: 0.6721
# Epoch 64/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1422 - accuracy: 0.9492 - val_loss: 1.5654 - val_accuracy: 0.6148
# Epoch 65/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1169 - accuracy: 0.9593 - val_loss: 1.4683 - val_accuracy: 0.6803
# Epoch 66/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1661 - accuracy: 0.9390 - val_loss: 1.4405 - val_accuracy: 0.6393
# Epoch 67/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1910 - accuracy: 0.9322 - val_loss: 2.1266 - val_accuracy: 0.5656
# Epoch 68/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2848 - accuracy: 0.9153 - val_loss: 1.3732 - val_accuracy: 0.6311
# Epoch 69/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1985 - accuracy: 0.9322 - val_loss: 1.4763 - val_accuracy: 0.6311
# Epoch 70/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2071 - accuracy: 0.9254 - val_loss: 1.8202 - val_accuracy: 0.6066
# Epoch 71/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1814 - accuracy: 0.9424 - val_loss: 1.4053 - val_accuracy: 0.6311
# Epoch 72/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1800 - accuracy: 0.9458 - val_loss: 1.7243 - val_accuracy: 0.6393
# Epoch 73/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1682 - accuracy: 0.9356 - val_loss: 1.6852 - val_accuracy: 0.5984
# Epoch 74/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1876 - accuracy: 0.9254 - val_loss: 1.5245 - val_accuracy: 0.6148
# Epoch 75/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1743 - accuracy: 0.9458 - val_loss: 1.4329 - val_accuracy: 0.6311
# Epoch 76/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1233 - accuracy: 0.9661 - val_loss: 1.5443 - val_accuracy: 0.6148
# Epoch 77/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1801 - accuracy: 0.9390 - val_loss: 1.4236 - val_accuracy: 0.6721
# Epoch 78/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1562 - accuracy: 0.9593 - val_loss: 1.7016 - val_accuracy: 0.6393
# Epoch 79/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0969 - accuracy: 0.9593 - val_loss: 1.5914 - val_accuracy: 0.6393
# Epoch 80/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0581 - accuracy: 0.9831 - val_loss: 1.7994 - val_accuracy: 0.6148
# Epoch 81/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1091 - accuracy: 0.9695 - val_loss: 1.6094 - val_accuracy: 0.6475
# Epoch 82/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1458 - accuracy: 0.9559 - val_loss: 1.6282 - val_accuracy: 0.6639
# Epoch 83/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1193 - accuracy: 0.9627 - val_loss: 1.5526 - val_accuracy: 0.6230
# Epoch 84/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1827 - accuracy: 0.9559 - val_loss: 1.4777 - val_accuracy: 0.6721
# Epoch 85/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1404 - accuracy: 0.9593 - val_loss: 1.6015 - val_accuracy: 0.6311
# Epoch 86/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2184 - accuracy: 0.9390 - val_loss: 1.7058 - val_accuracy: 0.6148
# Epoch 87/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1294 - accuracy: 0.9593 - val_loss: 1.6395 - val_accuracy: 0.5902
# Epoch 88/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1325 - accuracy: 0.9424 - val_loss: 1.7022 - val_accuracy: 0.6311
# Epoch 89/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4333 - accuracy: 0.8949 - val_loss: 1.6768 - val_accuracy: 0.6230
# Epoch 90/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2030 - accuracy: 0.9492 - val_loss: 1.4938 - val_accuracy: 0.5820
# Epoch 91/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1965 - accuracy: 0.9254 - val_loss: 1.4706 - val_accuracy: 0.6311
# Epoch 92/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0820 - accuracy: 0.9627 - val_loss: 1.2553 - val_accuracy: 0.6721
# Epoch 93/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0803 - accuracy: 0.9695 - val_loss: 1.5712 - val_accuracy: 0.6639
# Epoch 94/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0957 - accuracy: 0.9695 - val_loss: 1.5251 - val_accuracy: 0.6475
# Epoch 95/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1752 - accuracy: 0.9559 - val_loss: 1.2652 - val_accuracy: 0.6967
# Epoch 96/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0798 - accuracy: 0.9797 - val_loss: 1.7956 - val_accuracy: 0.6230
# Epoch 97/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0961 - accuracy: 0.9763 - val_loss: 1.5474 - val_accuracy: 0.6557
# Epoch 98/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1082 - accuracy: 0.9627 - val_loss: 1.4663 - val_accuracy: 0.5820
# Epoch 99/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0573 - accuracy: 0.9797 - val_loss: 1.3560 - val_accuracy: 0.6475
# Epoch 100/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0719 - accuracy: 0.9831 - val_loss: 1.2720 - val_accuracy: 0.7377

# %%
model.save('/content/drive/MyDrive/AI/10_Monan/Food.h5')

# %%
pic = image.load_img('/content/drive/MyDrive/AI/10_Monan/BANHXEO.jpg', target_size=(120,120)) 
plt.imshow(pic)
pic = img_to_array(pic)
pic = pic.reshape(1,120,120,3) 
pic = pic.astype('float32')
pic = pic/255
np.argmax(model.predict(pic), axis=1)
# Out:
# array([4])

# %%
# predict 
guess=np.argmax(model.predict(pic), axis=1)
#đặt điều kiện
if guess[0]==0:
  print("Loai do an: BANH MI")
if guess[0]==1:
  print("Loai do an: BANH PIA")
if guess[0]==2:
  print("Loai do an: BANH TIEU")
if guess[0]==3:
  print("Loai do an: BANH UOT")
if guess[0]==4:
  print("Loai do an: BANH XEO")
if guess[0]==5:
  print("Loai do an: CA RI")
if guess[0]==6:
  print("Loai do an: COM TAM")
if guess[0]==7:
  print("Loai do an: MI XAO")
if guess[0]==8:
  print("Loai do an: PHO")
if guess[0]==9:
  print("Loai do an: THIT KHO TAU")
# Out:
# Loai do an: BANH XEO
